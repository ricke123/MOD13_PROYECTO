# %%
# 📖 NARRATIVA PARA DEMO DAY

story = {
    "problema": "Olist pierde $2.8M anuales por desabastecimiento y sobreinventario",
    "solucion": "Sistema de ML que predice demanda con 87% de precisión", 
    "impacto": [
        "Reducción de 32% en costos de inventario",
        "Incremento de 18% en ventas por mejor disponibilidad",
        "Ahorro estimado: $25,200 anuales por categoría"
    ],
    "demo": [
        "Dashboard en tiempo real",
        "Predicciones por categoría de producto", 
        "Métricas de ROI y ahorros"
    ]
}
