# %%
import pandas as pd

df = pd.read_csv("../data/processed/TABLA_FINAL_MODULAR.csv")

df.head()
# Out:
#   order_month product_category_name  demand  unique_products  unique_orders  \
# 0     2016-09          beleza_saude       3                1              1
# 1     2016-10             alimentos       1                1              1
# 2     2016-10                 audio       2                2              2
# 3     2016-10            automotivo       8                8              8
# 4     2016-10                 bebes      11               10              9
#
#    unique_customers  unique_sellers  total_sales   avg_price   price_std  ...  \
# 0                 1               1       134.97   44.990000    0.000000  ...
# 1                 1               1        79.90   79.900000    0.000000  ...
# 2                 2               1       156.99   78.495000   75.667497  ...
# 3                 8               8      1128.26  141.032500  173.996594  ...
# 4                 9               6      1371.17  124.651818   99.291111  ...
#
# ...

# %%
for col in df.columns:
    print(f"Columna: {col} | Tipo de dato: {df[col].dtype}")
# Out:
# Columna: order_month | Tipo de dato: object
# Columna: product_category_name | Tipo de dato: object
# Columna: demand | Tipo de dato: int64
# Columna: unique_products | Tipo de dato: int64
# Columna: unique_orders | Tipo de dato: int64
# Columna: unique_customers | Tipo de dato: int64
# Columna: unique_sellers | Tipo de dato: int64
# Columna: total_sales | Tipo de dato: float64
# Columna: avg_price | Tipo de dato: float64
# Columna: price_std | Tipo de dato: float64
# Columna: price_min | Tipo de dato: float64
# Columna: price_max | Tipo de dato: float64
# Columna: total_freight | Tipo de dato: float64
# Columna: avg_freight | Tipo de dato: float64
# Columna: total_payments | Tipo de dato: float64
# Columna: avg_payment | Tipo de dato: float64
# Columna: payment_avg_mean | Tipo de dato: float64
# Columna: payment_count_mean | Tipo de dato: float64
# Columna: installments_avg_mean | Tipo de dato: float64
# Columna: avg_review_score | Tipo de dato: float64
# ...
